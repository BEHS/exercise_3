# %%
# %pip install geopandas

import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import shapefile
import folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
roads_shpfil = gpd.read_file(r"C:\Users\be81h\Documents\408_cel_\exercise_3\tl_2025_01_prisecroads\tl_2025_01_prisecroads.shp")

# %%
print(roads_shpfil)
# Out:
#             LINEARID                   FULLNAME RTTYP  MTFCC  \
# 0      1103266916245  Adelle Green Sanders Loop     M  S1200
# 1      1108296282294          Phenix City N Byp     M  S1100
# 2       110391540257          Phenix City N Byp     M  S1200
# 3       110391540256          Phenix City N Byp     M  S1200
# 4      1108296282287          Phenix City N Byp     M  S1100
# ...              ...                        ...   ...    ...
# 6736  11015682101938                      Hwy 5     M  S1200
# 6737     11084670365                State Rte 5     S  S1200
# 6738     11084671273                 US Hwy 278     U  S1200
# 6739   1103717805753                   11th Ave     M  S1200
# 6740     11084677507                Campbell Rd     M  S1200
#
#                                                geometry
# 0     LINESTRING (-87.28674 32.64503, -87.28656 32.6...
# 1     LINESTRING (-85.02065 32.49716, -85.02046 32.4...
# 2     LINESTRING (-85.02065 32.49716, -85.021 32.496...
# ...

# %%
roads_shpfil.plot()
plt.show()

# %%
name_column = 'FULLNAME'

most_common = (
    roads_shpfil.groupby(name_column)
    .size()
    .reset_index(name='count')
    .sort_values(by='count', ascending=False)
)

print(most_common.head(10))
# Out:
#           FULLNAME  count
# 1784     US Hwy 31    113
# 1490   State Rte 1    104
# 1662   State Rte 3    103
# 1772    US Hwy 231     98
# 1793    US Hwy 431     92
# 1686  State Rte 53     91
# 1522  State Rte 13     77
# 1604  State Rte 21     73
# 1791     US Hwy 43     71
# 1594   State Rte 2     68
